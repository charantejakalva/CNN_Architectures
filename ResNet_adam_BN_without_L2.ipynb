# %%
from tensorflow import Tensor
import keras,os
from keras.models import Sequential
import numpy as np
from keras.layers import Dense,Conv2D,MaxPool2D,Flatten,BatchNormalization,AveragePooling2D,ReLU
from keras.preprocessing.image import ImageDataGenerator
from keras.initializers import HeNormal
from keras import regularizers
from sklearn.metrics import recall_score,precision_score
from keras.layers import LeakyReLU
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.datasets import cifar100
# %load_ext tensorboard
from keras.layers import Input, Add
from keras.models import Model
from keras.optimizers import Adam,SGD
from keras.losses import categorical_crossentropy

# %%
(x_train,y_train),(x_test,y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
plt.imshow(x_train[0])

# %%
def normalize(X_train,X_test):
    #this function normalize inputs for zero mean and unit variance
    # it is used when training a model.
    # Input: training set and test set
    # Output: normalized training set and test set according to the trianing set statistics.
    mean = np.mean(X_train,axis=(0,1,2,3))
    std = np.std(X_train, axis=(0, 1, 2, 3))
    print(mean)
    print(std)
    X_train = (X_train-mean)/(std+1e-7)
    X_test = (X_test-mean)/(std+1e-7)
    return X_train, X_test

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = normalize(x_train, x_test)
# Out:
# 121.93584
# 68.38902

# %%
from keras.utils import to_categorical
y_train = keras.utils.to_categorical(y_train, 100)
y_test = keras.utils.to_categorical(y_test, 100)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
def create_res_net():
    
    inputs = Input(shape=(32, 32, 3))
    num_filters = 64
    kernel_size = 3
    t = BatchNormalization()(inputs)
    t = Conv2D(kernel_size=3, strides=1, filters=num_filters, padding="same")(t)
    t = BatchNormalization()(t)
    t = LeakyReLU(0.1)(t)

    t = MaxPool2D(pool_size=(2,2),strides=2)(t)

    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=num_filters,padding="same")(t)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=num_filters,padding="same")(y) 
    #y = BatchNormalization()(y)

    t = Conv2D(kernel_size=1, strides=1,filters=num_filters,padding="same")(t)
    #t = BatchNormalization()(t)
    y = Add()([t, y])
    a = LeakyReLU(0.1)(y)

    a = MaxPool2D(pool_size=(2,2),strides=2)(a)

    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=num_filters,padding="same")(a)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=num_filters,padding="same")(y) 

    a = Conv2D(kernel_size=1, strides=1,filters=num_filters,padding="same")(a)
    y = Add()([a, y])
    b = LeakyReLU(0.1)(y)

    y = Conv2D(kernel_size=kernel_size, strides=1, filters=128,padding="same")(b)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=128,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    b = Conv2D(kernel_size=1, strides=1,filters=128,padding="same")(b)
    y = Add()([b, y])
    c = LeakyReLU(0.1)(y)

    y = Conv2D(kernel_size=kernel_size, strides=1, filters=128,padding="same")(c)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=128,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    c = Conv2D(kernel_size=1, strides=1,filters=128,padding="same")(c)
    y = Add()([c, y])
    d = LeakyReLU(0.1)(y)

 
    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=256,padding="same")(d)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=256,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    d = Conv2D(kernel_size=1, strides=1,filters=256,padding="same")(d)
    y = Add()([d, y])
    f = LeakyReLU(0.1)(y)
 
    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=512,padding="same")(f)
    y = BatchNormalization()(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=512,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    f = Conv2D(kernel_size=1, strides=1,filters=512,padding="same")(f)
    y = Add()([f, y])
    h = LeakyReLU(0.1)(y)


    h = AveragePooling2D(4)(h)
    h = Flatten()(h)
    d1 = Dense(1024,activation = LeakyReLU(0.1))(h)
    outputs = Dense(100, activation='softmax')(d1)
    
    model = Model(inputs, outputs)
    learnrate = 1e-3
    #opt = Adam(lr=learnrate,clipnorm = 1.0)
    model.compile(
        optimizer= 'adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
from keras.callbacks import ModelCheckpoint,TensorBoard,EarlyStopping

# %%
model = create_res_net()
model.summary()

callback = ModelCheckpoint('resnet_adam_BN.h5',monitor='val_accuracy',save_best_only=True,save_weights_only=True,mode='auto')
early =  EarlyStopping(monitor='val_accuracy',min_delta = 0, patience = 20,verbose =1,mode = 'auto')
tensor_board = TensorBoard(log_dir='tb_logs/tensorboard',histogram_freq=1)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 3)    12          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 64)     36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     36928       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    73856       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 128)    8320        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    147584      leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 128)    0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 8, 8, 128)    0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    147584      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    16512       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    147584      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 128)    0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    295168      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    33024       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           conv2d_15[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 512)    1180160     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 512)    131584      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 512)    2359808     leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 512)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 8, 8, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 512)    0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          102500      dense[0][0]
# ==================================================================================================
# Total params: 7,494,640
# Trainable params: 7,492,202
# Non-trainable params: 2,438
# __________________________________________________________________________________________________

# %%
#Loading the saved weights

filename = '../weights/resnet_adam_BN_without_L2.h5'
model.load_weights(filename)
test_acc = model.evaluate(x_test,y_test)
test_acc
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 3.1605 - accuracy: 0.5224
# Prec: 0.5376208528946692
# Recall: 0.5224
# Accuracy: 0.5224

# %%
output = model.fit(x=x_train,y=y_train,batch_size = 128, epochs = 100,verbose =1,validation_data = (x_test,y_test),callbacks = [callback,early,tensor_board])
# Out:
# Epoch 1/100
#   1/391 [..............................] - ETA: 0s - loss: 4.7579 - accuracy: 0.0156WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/391 [..............................] - ETA: 24s - loss: 6.3827 - accuracy: 0.0078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0318s vs `on_train_batch_end` time: 0.0933s). Check your callbacks.
# 391/391 [==============================] - 23s 60ms/step - loss: 3.9091 - accuracy: 0.0983 - val_loss: 3.7159 - val_accuracy: 0.1289
# Epoch 2/100
# 391/391 [==============================] - 23s 58ms/step - loss: 3.0372 - accuracy: 0.2437 - val_loss: 2.9462 - val_accuracy: 0.2654
# Epoch 3/100
# 391/391 [==============================] - 23s 58ms/step - loss: 2.5002 - accuracy: 0.3485 - val_loss: 2.4090 - val_accuracy: 0.3684
# Epoch 4/100
# 391/391 [==============================] - 22s 57ms/step - loss: 2.1068 - accuracy: 0.4329 - val_loss: 2.2943 - val_accuracy: 0.4100
# Epoch 5/100
# 391/391 [==============================] - 22s 57ms/step - loss: 1.8055 - accuracy: 0.5015 - val_loss: 2.2082 - val_accuracy: 0.4381
# Epoch 6/100
# 391/391 [==============================] - 22s 57ms/step - loss: 1.5412 - accuracy: 0.5644 - val_loss: 2.1402 - val_accuracy: 0.4610
# Epoch 7/100
# 391/391 [==============================] - 22s 57ms/step - loss: 1.2895 - accuracy: 0.6269 - val_loss: 2.0927 - val_accuracy: 0.4763
# Epoch 8/100
# 391/391 [==============================] - 22s 57ms/step - loss: 1.0337 - accuracy: 0.6936 - val_loss: 2.0464 - val_accuracy: 0.5071
# Epoch 9/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.8109 - accuracy: 0.7517 - val_loss: 2.2972 - val_accuracy: 0.4926
# Epoch 10/100
# 391/391 [==============================] - 23s 58ms/step - loss: 0.6218 - accuracy: 0.8035 - val_loss: 2.3524 - val_accuracy: 0.5142
# Epoch 11/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.4757 - accuracy: 0.8479 - val_loss: 2.8239 - val_accuracy: 0.5069
# Epoch 12/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.3757 - accuracy: 0.8790 - val_loss: 2.8519 - val_accuracy: 0.5086
# Epoch 13/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.3333 - accuracy: 0.8930 - val_loss: 5.2176 - val_accuracy: 0.4414
# Epoch 14/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.2813 - accuracy: 0.9083 - val_loss: 3.1389 - val_accuracy: 0.5052
# Epoch 15/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.2441 - accuracy: 0.9212 - val_loss: 3.2075 - val_accuracy: 0.5095
# Epoch 16/100
# 391/391 [==============================] - 22s 58ms/step - loss: 0.2224 - accuracy: 0.9270 - val_loss: 3.1605 - val_accuracy: 0.5224
# Epoch 17/100
# 391/391 [==============================] - 23s 58ms/step - loss: 0.2379 - accuracy: 0.9229 - val_loss: 3.4646 - val_accuracy: 0.4976
# Epoch 18/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.2105 - accuracy: 0.9337 - val_loss: 3.4452 - val_accuracy: 0.5084
# Epoch 19/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1930 - accuracy: 0.9382 - val_loss: 3.3635 - val_accuracy: 0.5126
# Epoch 20/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1988 - accuracy: 0.9388 - val_loss: 3.6178 - val_accuracy: 0.4969
# Epoch 21/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1830 - accuracy: 0.9418 - val_loss: 3.7410 - val_accuracy: 0.5108
# Epoch 22/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1530 - accuracy: 0.9521 - val_loss: 4.0690 - val_accuracy: 0.5018
# Epoch 23/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.2107 - accuracy: 0.9362 - val_loss: 4.1063 - val_accuracy: 0.4980
# Epoch 24/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1613 - accuracy: 0.9492 - val_loss: 4.1241 - val_accuracy: 0.5026
# Epoch 25/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1417 - accuracy: 0.9562 - val_loss: 4.4849 - val_accuracy: 0.5037
# Epoch 26/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1807 - accuracy: 0.9462 - val_loss: 3.9480 - val_accuracy: 0.5118
# Epoch 27/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1685 - accuracy: 0.9503 - val_loss: 4.3645 - val_accuracy: 0.5116
# Epoch 28/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1446 - accuracy: 0.9587 - val_loss: 4.2776 - val_accuracy: 0.4953
# Epoch 29/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1846 - accuracy: 0.9477 - val_loss: 4.5528 - val_accuracy: 0.5072
# Epoch 30/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1316 - accuracy: 0.9613 - val_loss: 4.6377 - val_accuracy: 0.5063
# Epoch 31/100
# 391/391 [==============================] - 22s 58ms/step - loss: 0.1382 - accuracy: 0.9597 - val_loss: 4.7653 - val_accuracy: 0.5056
# Epoch 32/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1396 - accuracy: 0.9594 - val_loss: 4.8501 - val_accuracy: 0.5140
# Epoch 33/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1471 - accuracy: 0.9573 - val_loss: 4.5814 - val_accuracy: 0.5143
# Epoch 34/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1769 - accuracy: 0.9523 - val_loss: 4.5388 - val_accuracy: 0.5173
# Epoch 35/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1270 - accuracy: 0.9628 - val_loss: 4.8876 - val_accuracy: 0.5108
# Epoch 36/100
# 391/391 [==============================] - 22s 57ms/step - loss: 0.1506 - accuracy: 0.9592 - val_loss: 4.7111 - val_accuracy: 0.5064
# Epoch 00036: early stopping

# %%
test_acc = model.evaluate(x_test,y_test)
test_acc
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 4.7111 - accuracy: 0.5064
# [4.711078643798828, 0.5063999891281128]

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))

# %%
plt.plot(output.history["loss"])
plt.plot(output.history["val_loss"])
plt.legend(['train','test'])
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
plt.plot(output.history["accuracy"])
plt.plot(output.history["val_accuracy"])
plt.legend(['train accuracy','test accuracy'])
plt.title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
import seaborn as sns 

plt.figure(figsize = (100,100))  #This is the size of the image
heatM = sns.heatmap(confusion_matrix(y_true, y_pred), vmin = -1, vmax = 1,center = 0, cmap = sns.diverging_palette(20, 220, n = 200),  square = True, annot = True) #this are the caracteristics of the heatmap
heatM.set_ylim([100,0]) # This is the limit in y axis (number of features)
# Out:
# (100.0, 0.0)
