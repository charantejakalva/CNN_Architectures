# %%
from tensorflow import Tensor
import keras,os
from keras.models import Sequential
import numpy as np
from keras.layers import Dense,Conv2D,MaxPool2D,Flatten,BatchNormalization,AveragePooling2D,ReLU,Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.initializers import HeNormal
from keras import regularizers
from sklearn.metrics import recall_score,precision_score
from keras.layers import LeakyReLU
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.datasets import cifar100
# %load_ext tensorboard
from keras.layers import Input, Add
from keras.models import Model
from keras.optimizers import Adam,SGD
from keras.losses import categorical_crossentropy

# %%
(x_train,y_train),(x_test,y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
plt.imshow(x_train[0])

# %%
def normalize(X_train,X_test):
    #this function normalize inputs for zero mean and unit variance
    # it is used when training a model.
    # Input: training set and test set
    # Output: normalized training set and test set according to the trianing set statistics.
    mean = np.mean(X_train,axis=(0,1,2,3))
    std = np.std(X_train, axis=(0, 1, 2, 3))
    print(mean)
    print(std)
    X_train = (X_train-mean)/(std+1e-7)
    X_test = (X_test-mean)/(std+1e-7)
    return X_train, X_test

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = normalize(x_train, x_test)
# Out:
# 121.93584
# 68.38902

# %%
from keras.utils import to_categorical
y_train = keras.utils.to_categorical(y_train, 100)
y_test = keras.utils.to_categorical(y_test, 100)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
def create_res_net():
    
    inputs = Input(shape=(32, 32, 3))
    num_filters = 64
    kernel_size = 3
    #t = BatchNormalization()(inputs)
    t = Conv2D(kernel_size=3, strides=1, filters=num_filters, padding="same")(inputs)
    t = Dropout(0.1)(t)
    t = LeakyReLU(0.1)(t)

    t = MaxPool2D(pool_size=(2,2),strides=2)(t)

    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=num_filters,padding="same")(t)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=num_filters,padding="same")(y) 
    #y = Dropout(0.1)(y)

    t = Conv2D(kernel_size=1, strides=1,filters=num_filters,padding="same")(t)
    #t = Dropout(0.1)(t)
    y = Add()([t, y])
    a = LeakyReLU(0.1)(y)

    a = MaxPool2D(pool_size=(2,2),strides=2)(a)

    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=num_filters,padding="same")(a)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=num_filters,padding="same")(y) 

    a = Conv2D(kernel_size=1, strides=1,filters=num_filters,padding="same")(a)
    y = Add()([a, y])
    b = LeakyReLU(0.1)(y)

    y = Conv2D(kernel_size=kernel_size, strides=1, filters=128,padding="same")(b)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=128,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    b = Conv2D(kernel_size=1, strides=1,filters=128,padding="same")(b)
    y = Add()([b, y])
    c = LeakyReLU(0.1)(y)

    y = Conv2D(kernel_size=kernel_size, strides=1, filters=128,padding="same")(c)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=128,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    c = Conv2D(kernel_size=1, strides=1,filters=128,padding="same")(c)
    y = Add()([c, y])
    d = LeakyReLU(0.1)(y)
 
    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=256,padding="same")(d)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=256,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    d = Conv2D(kernel_size=1, strides=1,filters=256,padding="same")(d)
    y = Add()([d, y])
    f = LeakyReLU(0.1)(y)

   
    y = Conv2D(kernel_size=kernel_size, strides= 1, filters=512,padding="same")(f)
    y = Dropout(0.1)(y)
    y = LeakyReLU(0.1)(y)
    y = Conv2D(kernel_size=kernel_size, strides=1,filters=512,padding="same")(y)
    #y = LeakyReLU(0.1)(y)
    f = Conv2D(kernel_size=1, strides=1,filters=512,padding="same")(f)
    y = Add()([f, y])
    h = LeakyReLU(0.1)(y)


    h = AveragePooling2D(4)(h)
    h = Flatten()(h)
    d1 = Dense(1024,activation = LeakyReLU(0.1))(h)
    outputs = Dense(100, activation='softmax')(d1)
    
    model = Model(inputs, outputs)
    learnrate = 1e-3
    #opt = Adam(lr=learnrate,clipnorm = 1.0)
    model.compile(
        optimizer= 'adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
from keras.callbacks import ModelCheckpoint,TensorBoard,EarlyStopping

# %%
model = create_res_net()
model.summary()

callback = ModelCheckpoint('resnet_adam_dropout_without_L2.h5',monitor='val_accuracy',save_best_only=True,save_weights_only=True,mode='auto')
early =  EarlyStopping(monitor='val_accuracy',min_delta = 0, patience = 20,verbose =1,mode = 'auto')
tensor_board = TensorBoard(log_dir='tb_logs/tensorboard',histogram_freq=1)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 32, 32, 64)   0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 16, 64)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 64)     36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 64)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 64)     0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     36928       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    73856       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 128)    8320        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    147584      leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 128)    0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 8, 8, 128)    0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    147584      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    16512       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    147584      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 128)    0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    295168      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 256)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    33024       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           conv2d_15[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 512)    1180160     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 512)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 8, 8, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 512)    131584      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 512)    2359808     leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 512)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 8, 8, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 512)    0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          102500      dense[0][0]
# ==================================================================================================
# Total params: 7,489,764
# Trainable params: 7,489,764
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Loading the saved weights

filename = '../weights/resnet_adam_dropout_without_L2.h5'
model.load_weights(filename)
test_acc = model.evaluate(x_test,y_test)
test_acc
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))

# %%
output = model.fit(x=x_train,y=y_train,batch_size = 128, epochs = 100,verbose =1,validation_data = (x_test,y_test),callbacks = [callback,early,tensor_board])
# Out:
# Epoch 1/100
#   1/391 [..............................] - ETA: 0s - loss: 4.6014 - accuracy: 0.0156WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/391 [..............................] - ETA: 29s - loss: 5.1091 - accuracy: 0.0078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0369s vs `on_train_batch_end` time: 0.1116s). Check your callbacks.
# 391/391 [==============================] - 24s 62ms/step - loss: 4.2611 - accuracy: 0.0464 - val_loss: 3.8225 - val_accuracy: 0.0966
# Epoch 2/100
# 391/391 [==============================] - 23s 59ms/step - loss: 3.4675 - accuracy: 0.1613 - val_loss: 3.1386 - val_accuracy: 0.2274
# Epoch 3/100
# 391/391 [==============================] - 23s 60ms/step - loss: 2.8554 - accuracy: 0.2784 - val_loss: 2.6975 - val_accuracy: 0.3109
# Epoch 4/100
# 391/391 [==============================] - 24s 60ms/step - loss: 2.4014 - accuracy: 0.3711 - val_loss: 2.3516 - val_accuracy: 0.3895
# Epoch 5/100
# 391/391 [==============================] - 24s 62ms/step - loss: 2.0443 - accuracy: 0.4515 - val_loss: 2.1642 - val_accuracy: 0.4368
# Epoch 6/100
# 391/391 [==============================] - 24s 62ms/step - loss: 1.7349 - accuracy: 0.5216 - val_loss: 2.1362 - val_accuracy: 0.4487
# Epoch 7/100
# 391/391 [==============================] - 24s 61ms/step - loss: 1.4843 - accuracy: 0.5806 - val_loss: 2.0684 - val_accuracy: 0.4733
# Epoch 8/100
# 391/391 [==============================] - 24s 61ms/step - loss: 1.2341 - accuracy: 0.6414 - val_loss: 2.0595 - val_accuracy: 0.4851
# Epoch 9/100
# 391/391 [==============================] - 24s 62ms/step - loss: 1.0075 - accuracy: 0.7001 - val_loss: 2.1891 - val_accuracy: 0.4892
# Epoch 10/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.8225 - accuracy: 0.7501 - val_loss: 2.3342 - val_accuracy: 0.4844
# Epoch 11/100
# 391/391 [==============================] - 24s 62ms/step - loss: 0.6807 - accuracy: 0.7909 - val_loss: 2.4307 - val_accuracy: 0.4733
# Epoch 12/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.5696 - accuracy: 0.8210 - val_loss: 2.7527 - val_accuracy: 0.4819
# Epoch 13/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.5110 - accuracy: 0.8401 - val_loss: 2.7540 - val_accuracy: 0.4799
# Epoch 14/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.4438 - accuracy: 0.8593 - val_loss: 3.0000 - val_accuracy: 0.4802
# Epoch 15/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.4113 - accuracy: 0.8718 - val_loss: 3.1256 - val_accuracy: 0.4774
# Epoch 16/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3848 - accuracy: 0.8790 - val_loss: 3.6562 - val_accuracy: 0.4715
# Epoch 17/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3600 - accuracy: 0.8887 - val_loss: 3.5348 - val_accuracy: 0.4779
# Epoch 18/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3536 - accuracy: 0.8907 - val_loss: 3.5352 - val_accuracy: 0.4785
# Epoch 19/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3323 - accuracy: 0.8967 - val_loss: 3.7146 - val_accuracy: 0.4760
# Epoch 20/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3175 - accuracy: 0.9030 - val_loss: 3.6801 - val_accuracy: 0.4730
# Epoch 21/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3121 - accuracy: 0.9054 - val_loss: 3.6756 - val_accuracy: 0.4777
# Epoch 22/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.2944 - accuracy: 0.9103 - val_loss: 3.6700 - val_accuracy: 0.4761
# Epoch 23/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3056 - accuracy: 0.9094 - val_loss: 3.8160 - val_accuracy: 0.4693
# Epoch 24/100
# 391/391 [==============================] - 24s 62ms/step - loss: 0.2886 - accuracy: 0.9138 - val_loss: 3.8997 - val_accuracy: 0.4695
# Epoch 25/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.2947 - accuracy: 0.9112 - val_loss: 4.1948 - val_accuracy: 0.4651
# Epoch 26/100
# 391/391 [==============================] - 24s 62ms/step - loss: 0.2850 - accuracy: 0.9162 - val_loss: 4.2518 - val_accuracy: 0.4702
# Epoch 27/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3023 - accuracy: 0.9089 - val_loss: 4.6460 - val_accuracy: 0.4723
# Epoch 28/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.2564 - accuracy: 0.9249 - val_loss: 4.1894 - val_accuracy: 0.4552
# Epoch 29/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.2693 - accuracy: 0.9212 - val_loss: 3.8570 - val_accuracy: 0.4676
# Epoch 00029: early stopping

# %%
test_acc = model.evaluate(x_test,y_test)
test_acc
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 3.8570 - accuracy: 0.4676
# [3.85695743560791, 0.4675999879837036]

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.5132952578656209
# Recall: 0.4892
# Accuracy: 0.4892

# %%
plt.plot(output.history["loss"])
plt.plot(output.history["val_loss"])
plt.legend(['train','test'])
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
plt.plot(output.history["accuracy"])
plt.plot(output.history["val_accuracy"])
plt.legend(['train accuracy','test accuracy'])
plt.title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
import seaborn as sns 

plt.figure(figsize = (100,100))  #This is the size of the image
heatM = sns.heatmap(confusion_matrix(y_true, y_pred), vmin = -1, vmax = 1,center = 0, cmap = sns.diverging_palette(20, 220, n = 200),  square = True, annot = True) #this are the caracteristics of the heatmap
heatM.set_ylim([100,0]) # This is the limit in y axis (number of features)
# Out:
# (100.0, 0.0)
